# %% [markdown]
# ## feature scaling (feature transform)
# # standardization

# %%
conda update matplotlib
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Admin\anaconda3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2026.8.13  |       haa95532_0         107 KB
#     certifi-2026.7.22          |  py313haa95532_0         135 KB
#     cycler-0.12.1              |  py313haa95532_0          20 KB
#     fonttools-4.63.0           |  py313h1c6eee0_0         5.2 MB
#     freetype-2.14.1            |       hfbffc0b_0         514 KB
#     kiwisolver-1.5.0           |  py313hd7fb8db_0          83 KB
#     libpng-1.6.56              |       h2854ad3_0         239 KB
#     matplotlib-3.11.0          |  py313haa95532_0           7 KB
# ...

# %%
import pandas as pd # data processing 
import numpy as np   # linear algebra
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 311   39            96000          1
# 213   35            58000          0
# 393   60            42000          1
# 163   35            38000          0
# 35    35            27000          0

# %% [markdown]
# ## train_test_split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    df.drop("Purchased", axis=1), df["Purchased"], test_size=0.3
)

x_train.shape,x_test.shape
# Out:
# ((280, 2), (120, 2))

# %% [markdown]
# ## StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train)
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
scaler.mean_
# Out:
# array([3.80428571e+01, 7.13285714e+04])

# %%
x_train_scaled = pd.DataFrame(scaler.transform(x_train), columns=x_train.columns)
x_test_scaled = pd.DataFrame(scaler.transform(x_test), columns=x_test.columns)

x_train_scaled.sample(3)
# Out:
#           Age  EstimatedSalary
# 163  1.580195        -0.922413
# 142 -0.190369        -0.608556
# 232 -1.401807        -0.152037

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr_scaled = LogisticRegression()

# %%
lr.fit(X_train,y_train)
lr_scaled.fit(x_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)
y_pred_scaler = lr_scaled.predict(x_test_scaled)

# %%
from sklearn.metrics import accuracy_score

# %%
print("actual",accuracy_score (y_test,y_pred))
print("scaled",accuracy_score (y_test,y_pred_scaler))
# Out:
# actual 0.7416666666666667
# scaled 0.875

# %%
print("actual", accuracy_score(y_test, y_pred) * 100)
print("scaled", accuracy_score(y_test, y_pred_scaler) * 100)
# Out:
# actual 74.16666666666667
# scaled 87.5
