# %%
import pandas as pd

# %%
df = pd.read_csv('tested_titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# !pip install ydata-profiling
# Out:
# ...
#   Using cached ydata_profiling-4.18.4-py2.py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached matplotlib-3.10.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached phik-0.12.5-cp313-cp313-win_amd64.whl.metadata (5.6 kB)
# ...
#   Using cached ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached wordcloud-1.9.6-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# ...
# Using cached ydata_profiling-4.18.4-py2.py3-none-any.whl (400 kB)
# Using cached ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Using cached matplotlib-3.10.0-cp313-cp313-win_amd64.whl (8.0 MB)
# Using cached phik-0.12.5-cp313-cp313-win_amd64.whl (678 kB)
# Using cached wordcloud-1.9.6-cp313-cp313-win_amd64.whl (306 kB)
# ...
#
#    ---------------------------------------- 0/5 [matplotlib]
#    ---------------------------------------- 0/5 [matplotlib]
#    ---------------------------------------- 0/5 [matplotlib]
#    ---------------------------------------- 0/5 [matplotlib]
# ...

# %%
# !pip install ydata-profiling --user
# Out:
# ...
#   Using cached ydata_profiling-4.18.4-py2.py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached phik-0.12.5-cp313-cp313-win_amd64.whl.metadata (5.6 kB)
# ...
#   Using cached ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached wordcloud-1.9.6-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# ...
# Using cached ydata_profiling-4.18.4-py2.py3-none-any.whl (400 kB)
# Using cached ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Using cached phik-0.12.5-cp313-cp313-win_amd64.whl (678 kB)
# Using cached wordcloud-1.9.6-cp313-cp313-win_amd64.whl (306 kB)
# ...
#
#    ---------- ----------------------------- 1/4 [wordcloud]
#    ---------- ----------------------------- 1/4 [wordcloud]
#    ---------- ----------------------------- 1/4 [wordcloud]
#    ---------- ----------------------------- 1/4 [wordcloud]
#    -------------------- ------------------- 2/4 [phik]
#    -------------------- ------------------- 2/4 [phik]
#    -------------------- ------------------- 2/4 [phik]
# ...

# %%
import sys
sys.path.append(r'C:\Users\Admin\AppData\Roaming\Python\Python313\site-packages')

from ydata_profiling import ProfileReport

prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# Bad value in file WindowsPath('C:/Users/Admin/anaconda3/Lib/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle'), line 162 ('mathtext.default: normal  # The default font to use for math.'): Key mathtext.default: 'normal' is not a valid value for mathtext.default; supported values are ['rm', 'cal', 'bfit', 'it', 'tt', 'sf', 'bf', 'default', 'bb', 'frak', 'scr', 'regular']
#
# Bad key axes3d.depthshade in file C:\Users\Admin\anaconda3\Lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle, line 225 ('axes3d.depthshade   : False   # depth shade for 3D scatter plots')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.10.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# ...

# %%
from ydata_profiling import ProfileReport

# Generate the report for your DataFrame (df)
profile = ProfileReport(df, title="Profiling Report")

# Display directly inside your notebook
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling v4.18.4&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-09-08 11:50:59.841187&quot; name=date&gt;&lt;title&gt;Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...
