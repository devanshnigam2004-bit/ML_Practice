# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
sales = pd.Series([1,2,3])

# %%
sales
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
sales[0:3]
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
sales[2]
# Out:
# np.int64(3)

# %%
sales.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
sales.values
# Out:
# array([1, 2, 3])

# %%
sales.dtype
# Out:
# dtype('int64')

# %%
sales.head()
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
sales.tail(1)
# Out:
# 2    3
# dtype: int64

# %%
sales1 = pd.Series([1,2,7,8,9,4,5,3,4,5,3,6])

# %%
sales1.head()
# Out:
# 0    1
# 1    2
# 2    7
# 3    8
# 4    9
# dtype: int64

# %%
sales1.sort_values()
# Out:
# 0     1
# 1     2
# 7     3
# 10    3
# 5     4
# 8     4
# 6     5
# 9     5
# 11    6
# 2     7
# 3     8
# 4     9
# dtype: int64

# %%
sales1.isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# dtype: bool

# %%
sales1.count()
# Out:
# np.int64(12)

# %%
sales1 +1
# Out:
# 0      2
# 1      3
# 2      8
# 3      9
# 4     10
# 5      5
# 6      6
# 7      4
# 8      5
# 9      6
# 10     4
# 11     7
# dtype: int64

# %%
sales1*2
# Out:
# 0      2
# 1      4
# 2     14
# 3     16
# 4     18
# 5      8
# 6     10
# 7      6
# 8      8
# 9     10
# 10     6
# 11    12
# dtype: int64

# %%
sales1
# Out:
# 0     1
# 1     2
# 2     7
# 3     8
# 4     9
# 5     4
# 6     5
# 7     3
# 8     4
# 9     5
# 10    3
# 11    6
# dtype: int64

# %%
data = pd.DataFrame({
    'name' : ['anan','ben','forb'],
    'age' : [22,34,12]
})

# %%
data
# Out:
#    name  age
# 0  anan   22
# 1   ben   34
# 2  forb   12

# %%
data = pd.DataFrame({
    's' : sales, 's1' : sales1
})
data
# Out:
#       s  s1
# 0   1.0   1
# 1   2.0   2
# 2   3.0   7
# 3   NaN   8
# 4   NaN   9
# 5   NaN   4
# 6   NaN   5
# 7   NaN   3
# 8   NaN   4
# 9   NaN   5
# 10  NaN   3
# 11  NaN   6

# %%
data.s.isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# Name: s, dtype: bool

# %%
data.shape
# Out:
# (12, 2)

# %%
data.columns
# Out:
# Index(['s', 's1'], dtype='object')

# %%
data.s1.shape
# Out:
# (12,)

# %%
sales.shape
# Out:
# (3,)

# %%
data.loc[3,'s1']
# Out:
# np.int64(8)

# %%
data.iloc[3,1]
# Out:
# np.int64(8)

# %%
data.info
# Out:
# <bound method DataFrame.info of       s  s1
# 0   1.0   1
# 1   2.0   2
# 2   3.0   7
# 3   NaN   8
# 4   NaN   9
# 5   NaN   4
# 6   NaN   5
# 7   NaN   3
# 8   NaN   4
# 9   NaN   5
# 10  NaN   3
# 11  NaN   6>

# %%
data[data['s1']== 2]
# Out:
#      s  s1
# 1  2.0   2

# %%
multi_data = pd.DataFrame({
    'name' : ['dev','jay','mark','anna'],
    'park' : ['a','a','b','b'],
    'Lemonade' : [2,3,5,2]
}).set_index(['park','name'])

# %%
multi_data
# Out:
#            Lemonade
# park name
# a    dev          2
#      jay          3
# b    mark         5
#      anna         2

# %%
multi_data.query('Lemonade>=3')
# Out:
#            Lemonade
# park name
# a    jay          3
# b    mark         5

# %%
data.s1.drop_duplicates()
# Out:
# 0     1
# 1     2
# 2     7
# 3     8
# 4     9
# 5     4
# 6     5
# 7     3
# 11    6
# Name: s1, dtype: int64

# %%
data
# Out:
#       s  s1
# 0   1.0   1
# 1   2.0   2
# 2   3.0   7
# 3   NaN   8
# 4   NaN   9
# 5   NaN   4
# 6   NaN   5
# 7   NaN   3
# 8   NaN   4
# 9   NaN   5
# 10  NaN   3
# 11  NaN   6
